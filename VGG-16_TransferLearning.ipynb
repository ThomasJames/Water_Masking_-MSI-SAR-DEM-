# %% [markdown]
# <a href="https://colab.research.google.com/github/ThomasJames/CNN_for_EO/blob/master/VGG-16_TransferLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from torch import nn
